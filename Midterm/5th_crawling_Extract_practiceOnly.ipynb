# %% [markdown]
# ## Practice ranking crawling

# %%
html_a = urlopen('https://www.koreapas.com/bbs/main.php'); html_a
bsObject_a = BeautifulSoup(html_a, "html.parser")

# %%
bsObject_a
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="고려대학교 고파스" name="title">
# <meta content="고려대학교 고파스" property="og:title"/>
# <meta content="고대 재학생,졸업생이 함께하는 온라인 커뮤니티입니다." name="description"/>
# <meta content="고대 재학생,졸업생이 함께하는 온라인 커뮤니티입니다." property="og:description"/>
# <meta content="고려대,고대,민족고대,korea univ,고펑,고파스,koreapas" name="keywords"/>
# <meta content="https://www.koreapas.com/bbs/koreapas_kakao4.png" property="og:image"/>
# <link href="https://www.koreapas.com/bbs/koreapas_kakao4.png" rel="image_src"/>
# <title>고파스</title>
# <link href="https://www.koreapas.com/Icon-192.png?v=20170926" rel="icon" type="image/png"/>
# ...

# %%
for i in range(0,10):
    li = bsObject_a.select('span.number')
    info = bsObject_a.findAll("span", {"style":"padding-left:2px;font-size:13px;color:#4a4a4a;"})
    #ranking = bsObject_a.select('b')
    #print(li)
    #print(ranking)
    rank = li[i].get_text()
    #print(type(rank))
    ranker = info[i].get_text()
    print(rank, ranker)
    
######### junk #################################################################################
#rank_num = bsObject_a.find("span", {"class":"number"})
#print(rank_num)

#for i in range(0,10):
    #li = bsObject_a.findAll("span", {"class":"number"}) 
    #print(li)
    #ranknum[i] = li.select('span')[0].get_text()
   

 
#print(info)



    
    
    #ranker = li.select('b')[0].get_text()
    #print(rank, ranker)


#rank = li.select('span')
#li.selectAll('span')[0].get_text()
#ranknum = li.select('span')[0].get_text()

    
#for n in range(1):
    

    

    
    #rank_ch = li.select('span')[0].get_text()
    #print(rank_ch)
    
    #listing =
    
    #title = li.select('b')[0].get_text()
    #print(rank_ch, title) 


    #print(li);
    #rank = bsObject_a.find("span", {"class":"number"}) 
    #print(rank)
    
    #ranking = rank.select('span')[0].get_text()
    #rank_ch = li.select('span')[0].get_text()
    
    #title = li.select('b')[0].get_text()
    #print(title)
    #author = dt.next_sibling.next_sibling.select('a')[0].get_text()
    #publisher = dt.next_sibling.next_sibling.get_text().split()[-1]
    #print(n+1, title, author, publisher)
# Out:
# 1 여성상위
# 2 개운사예수
# 3 07입실렌티
# 4 예비군
# 5 여자친구에게민감한
# 6 한추사건
# 7 에어팟
# 8 와세다
# 9 학식
# 10 과잠

# %%
# Create a file to write to, add headers row
with open('crawlingKoreaPas.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['순위', '실시간 검색어'])
        
    for i in range(0,10):
        li = bsObject_a.select('span.number')
        info = bsObject_a.findAll("span", {"style":"padding-left:2px;font-size:13px;color:#4a4a4a;"})
    #ranking = bsObject_a.select('b')
    #print(li)
    #print(ranking)
        rank = li[i].get_text()
    #print(type(rank))
        ranker = info[i].get_text()
        print(rank, ranker)
        writer.writerow([rank, ranker])
# Out:
# 1 여성상위
# 2 개운사예수
# 3 07입실렌티
# 4 예비군
# 5 여자친구에게민감한
# 6 한추사건
# 7 에어팟
# 8 와세다
# 9 학식
# 10 과잠

# %% [markdown]
# ## Dump

# %%
# _*_ coding: UTF-8 _*_
from urllib.request import urlopen ## import urllib also possible
from bs4 import BeautifulSoup
import csv

# %%
html_b = urlopen('http://www.daum.net'); html_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0bf27b90ac12> in <module>
# ----> 1 html_b = urlopen('http://www.daum.net'); html_b
#
# NameError: name 'urlopen' is not defined

# %%
bsObject_b = BeautifulSoup(html_b, "html.parser"); bsObject_b
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="https://www.daum.net/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Daum" property="og:title"/>
# <meta content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image"/>
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description"/>
# <meta content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task"/>
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task"/>
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task"/>
# <meta content="origin" name="referrer"/>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# @charset "utf-8";
# ...

# %%
bsObject_b.html
# Out:
# <html class="" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="https://www.daum.net/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Daum" property="og:title"/>
# <meta content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image"/>
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description"/>
# <meta content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task"/>
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task"/>
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task"/>
# <meta content="origin" name="referrer"/>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# @charset "utf-8";
# ...

# %%
bsObject_b.head.title
# Out:
# <title>Daum</title>

# %%
bsObject_a

# %%
kopas = BeautifulSoup(html_b, "html.parser")

# %%
kopas

# %%
# _*_ coding: UTF-8 _*_
from urllib.request import urlopen ## import urllib also possible
from bs4 import BeautifulSoup
import csv
